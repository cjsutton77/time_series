# %% [markdown]
# # Prepare and Analyze Time Series - Milestone 1

# %% [markdown]
# This Jupyter notebook serves as an exercise workflow to Milestone 1 of the liveProject on End-to-end Time Series Forecasting with Deep Learning.
#
# You can upload this notebook to Colab and work from there. Alternatively, you can also work on this notebook in your local environment.

# %% [markdown]
# Our aim in this Milestone is to perform preliminary data processing and cleaning to have preprocessed data ready, as shown by the red dotted box in the diagram below.

# %% [markdown]
# ![Milestone 1](https://s3.ap-southeast-1.amazonaws.com/www.jiahao.io/manning/project1_milestone_1.png)

# %% [markdown]
# ## Importing Necessary Libraries and Functions

# %% [markdown]
# Let us first import the necessary libraries and load the data that we will be working with throughout this Milestone.
#
# The data (data/sales.csv) that we are using is a daily retail sales dataset modified from the [M5 competition data](https://www.kaggle.com/c/m5-forecasting-accuracy/data).
#
# In this liveProject, you are a data scientist at a large retailer and your challenge is to forecast the sales of the respective stores by each category for the next 28 days.

# %% [markdown]
# <ins>Instructions</ins>:<br>
# - We have written the code to import the libraries so you can just run it as-is. If you need other libraries while working on this notebook, please feel free to add the library to this cell below.

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %matplotlib inline

# suppress pandas SettingWithCopyWarning 
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Previewing the Sales Data

# %% [markdown]
# Let us first have a preview of the data to understand what we will be working with.

# %% [markdown]
# <ins>Instructions</ins>:<br>
# - Read in the data *sales.csv* from the data folder into a pandas dataframe and preview the first 5 rows.
#
# <ins>Note</ins>:<br>
# - If you are running this notebook in Colab, please upload *sales.csv* from the data folder.

# %% [markdown]
# <ins>Hints</ins> (click when needed):<br>
# - [Uploading files to Colab from your local file system](https://colab.research.google.com/notebooks/io.ipynb)
# - [Loading CSV data](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)
# - [Pandas `head` method to preview first 5 rows of dataframe `df`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html)

# %%
sales = pd.read_csv('./sales.csv')

# %%
# load data and view first 5 rows
sales.head()
# Out:
#          date store_id cat_id    sales
# 0  2011-01-29     TX_1  FOODS  3950.35
# 1  2011-01-30     TX_1  FOODS  3844.97
# 2  2011-01-31     TX_1  FOODS  2888.03
# 3  2011-02-01     TX_1  FOODS  3631.28
# 4  2011-02-02     TX_1  FOODS  3072.18

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58230 entries, 0 to 58229
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      58230 non-null  object
#  1   store_id  58230 non-null  object
#  2   cat_id    58230 non-null  object
#  3   sales     58230 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# You should see from the data preview that there are 4 columns with ~58k rows. The daily sales (column: `sales`) for each store (column: `store_id`) and category (column: `cat_id`) are listed in each row.
#
# If we generate the unique value count of the `store_id` and `cat_id`, we will see that there are 10 stores and 3 categories.

# %% [markdown]
# <ins>Instruction</ins>:<br>
# - Verify the number of unique values of `store_id` and `cat_id` each.

# %% [markdown]
# <ins>Hints</ins>:<br>
# - [Pandas `nunique` method](https://pandas.pydata.org/docs/reference/api/pandas.Series.nunique.html)

# %%
# unique count of store_id and cat_id
sales.store_id.unique()
# Out:
# array(['TX_1', 'TX_2', 'TX_3', 'CA_1', 'CA_2', 'CA_3', 'CA_4', 'WI_1',
#        'WI_2', 'WI_3'], dtype=object)

# %% [markdown]
# And in terms of the time period, our sales data start from 2011 to 2016. We also set the `date` column to datetime format.

# %% [markdown]
# <ins>Instructions</ins>:<br>
# - Verify the date range of the `sales` data

# %% [markdown]
# <ins>Hints</ins> (click when needed):<br>
# - [Pandas Datetime format](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html)

# %%
# verify max and min

sales.date = pd.to_datetime(sales.date)

# %%
sales.date.min()
# Out:
# Timestamp('2011-01-29 00:00:00')

# %%
sales.date.max()
# Out:
# Timestamp('2016-05-22 00:00:00')

# %% [markdown]
# ## Processing of Data

# %% [markdown]
# There are 3 common data quality issues to check for time series data:
# 1. Irregular time series
# 2. Outliers
# 3. Missing data

# %% [markdown]
# ### Data quality issue - Irregular time series

# %% [markdown]
# In our case, our sales data is of daily frequency. However, the data may possibly miss out some dates (see point 1 in image below) or added more rows for the same date (see point 2 in image below). Hence, we need to ensure that every date is accounted by exactly one row.
#
# For the scenario of point 2 in image below, we will also need to check with the data owner on the proper treatment, i.e., do we add up the sales of both rows to get sales for 2011-02-19 or do we just keep the row with time 00:00:00 because the data is a snapshot of sales?

# %% [markdown]
# ![Irregular Time Series](https://s3.ap-southeast-1.amazonaws.com/www.jiahao.io/manning/irregular_time_period.PNG)

# %% [markdown]
# <ins>Instruction</ins>:<br>
# - Check for duplicated dates within a store and category group

# %% [markdown]
# <ins>Hints</ins> (click when needed):<br>
# - [Pandas duplicated](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html)

# %%
# check for duplicate dates within a store and category group
any(sales[['store_id','cat_id','date']].duplicated())
# Out:
# False

# %%
# no duplicates where store_id, cat_id, and date are all the same

# %% [markdown]
# You should find that there is no duplicated date in a store and category group.
#
# Next let's try to see if there is missing date in between the start and end date of sales.

# %% [markdown]
# <ins>Instructions</ins>:<br>
# Generate dataframe with the daily dates in between the start and end dates of sales. Then check if there is any missing date(s) in between.

# %% [markdown]
# <ins>Hints</ins> (click when needed):<br>
# - [Pandas date_range](https://pandas.pydata.org/docs/reference/api/pandas.date_range.html)

# %%
# generate daily dates between the start and end of sales
# merge the dates dataframe with sales dataframe to check for missing dates
dailies = pd.date_range(start='01/29/2011', end='5/22/2016')
dailies
# Out:
# DatetimeIndex(['2011-01-29', '2011-01-30', '2011-01-31', '2011-02-01',
#                '2011-02-02', '2011-02-03', '2011-02-04', '2011-02-05',
#                '2011-02-06', '2011-02-07',
#                ...
#                '2016-05-13', '2016-05-14', '2016-05-15', '2016-05-16',
#                '2016-05-17', '2016-05-18', '2016-05-19', '2016-05-20',
#                '2016-05-21', '2016-05-22'],
#               dtype='datetime64[ns]', length=1941, freq='D')

# %%
day = pd.Series(dailies)
day.name = 'day'

# %%
sales_merge = pd.merge(sales,day,how='inner', left_index=True, right_index=True)

# %%
sales_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1941 entries, 0 to 1940
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      1941 non-null   datetime64[ns]
#  1   store_id  1941 non-null   object
#  2   cat_id    1941 non-null   object
#  3   sales     1941 non-null   float64
#  4   day       1941 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(2)
# memory usage: 91.0+ KB

# %% [markdown]
# Luckily for us, there is no missing date in between. If there is any, the `sales` value will be null and we can impute them later.

# %% [markdown]
# ### Data quality issue - Outliers

# %% [markdown]
# There are various ways to check for outliers in time series. Here, we use the Interquartile Range (IQR) method mentioned in the book [Forecasting: Principles and Practice](https://otexts.com/fpp3/missing-outliers.html) by Rob J Hyndman and George Athanasopoulos. However, we modified the method a little by detrending the time series first before applying the IQR method.

# %% [markdown]
# <ins>Instructions</ins>:<br>
# - Code the IQR method and implement it on the sales data. Take care to check for outliers by each store and category group. The sales dataframe should have a column named `anomaly` that will indicate each outlier as True and non-outliers as False.
# - Detrend the sales by each time series before applying the IQR method.

# %% [markdown]
# <ins>Hints</ins> (click when needed):<br>
# - [Pandas quantile](https://pandas.pydata.org/docs/reference/api/pandas.Series.quantile.html)
# - [Scipy detrend](https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.detrend.html)

# %%
from scipy import signal

# %%
sales.head()
# Out:
#         date store_id cat_id    sales
# 0 2011-01-29     TX_1  FOODS  3950.35
# 1 2011-01-30     TX_1  FOODS  3844.97
# 2 2011-01-31     TX_1  FOODS  2888.03
# 3 2011-02-01     TX_1  FOODS  3631.28
# 4 2011-02-02     TX_1  FOODS  3072.18

# %%
sales[sales['store_id'] == 'TX_1']
# Out:
#            date store_id     cat_id    sales
# 0    2011-01-29     TX_1      FOODS  3950.35
# 1    2011-01-30     TX_1      FOODS  3844.97
# 2    2011-01-31     TX_1      FOODS  2888.03
# 3    2011-02-01     TX_1      FOODS  3631.28
# 4    2011-02-02     TX_1      FOODS  3072.18
# ...         ...      ...        ...      ...
# 5818 2016-05-18     TX_1  HOUSEHOLD  3539.09
# 5819 2016-05-19     TX_1  HOUSEHOLD  2864.29
# 5820 2016-05-20     TX_1  HOUSEHOLD  3900.31
# 5821 2016-05-21     TX_1  HOUSEHOLD  4653.96
# 5822 2016-05-22     TX_1  HOUSEHOLD  5228.94
#
# [5823 rows x 4 columns]

# %%
def q(val,hi=1,lo=0):
  if (val >= lo) and (val <= hi ):
    return False
  else:
    return True

# %%
stores = sales['store_id'].unique()
stores
# Out:
# array(['TX_1', 'TX_2', 'TX_3', 'CA_1', 'CA_2', 'CA_3', 'CA_4', 'WI_1',
#        'WI_2', 'WI_3'], dtype=object)

# %%
cat = sales['cat_id'].unique()
cat
# Out:
# array(['FOODS', 'HOBBIES', 'HOUSEHOLD'], dtype=object)

# %%
def outlier_detection(df):
    Q1 = df['dtrend'].quantile(0.25)
    Q3 = df['dtrend'].quantile(0.75)
    IQR = Q3 - Q1
    df['anomaly'] = (df.dtrend >= Q3 + 1.5*IQR) | (df.dtrend <= Q1 - 1.5*IQR)
    return df

# %%
ds = []
for i in stores:
    for j in cat:
        df = sales[(sales['cat_id'] == j) & (sales['store_id'] == i)]
        df['dtrend'] = signal.detrend(df['sales'])
        df_out = outlier_detection(df)
        ds.append(df_out)

# %%
merged = pd.concat(ds)
merged
# Out:
#             date store_id     cat_id    sales       dtrend  anomaly
# 0     2011-01-29     TX_1      FOODS  3950.35  -160.500963    False
# 1     2011-01-30     TX_1      FOODS  3844.97  -266.532119    False
# 2     2011-01-31     TX_1      FOODS  2888.03 -1224.123274    False
# 3     2011-02-01     TX_1      FOODS  3631.28  -481.524430    False
# 4     2011-02-02     TX_1      FOODS  3072.18 -1041.275586    False
# ...          ...      ...        ...      ...          ...      ...
# 58225 2016-05-18     WI_3  HOUSEHOLD  2225.31  -387.841124    False
# 58226 2016-05-19     WI_3  HOUSEHOLD  2468.50  -144.880549    False
# 58227 2016-05-20     WI_3  HOUSEHOLD  3664.25  1050.640026    False
# 58228 2016-05-21     WI_3  HOUSEHOLD  3487.02   873.180600    False
# 58229 2016-05-22     WI_3  HOUSEHOLD  3566.90   952.831175    False
#
# [58230 rows x 6 columns]

# %%
plt.plot(merged[(merged['cat_id']=='FOODS') & (merged['store_id'] == 'TX_1')].date,
            merged[(merged['cat_id']=='FOODS') & (merged['store_id'] == 'TX_1')].sales)
plt.plot(sales[(merged['cat_id']=='FOODS') & (merged['store_id'] == 'TX_1')].date,
            merged[(merged['cat_id']=='FOODS') & (merged['store_id'] == 'TX_1')].dtrend)

# %% [markdown]
# Let's take a look at how our outlier detection method performs.
#
# In general, the method is able to capture most of the outliers (as seen from the diagrams below) that our human judgement would also determine to be outlying points. There are some outlying points that were missed out but we shall see in a while what these points may be and we can manually mark them as outlier if necessary.
#
# We also noticed that some of the points towards the tail end of the time series for the store *CA_2* and category *FOODS* seem to be wrongly marked as outliers. We can unmark these points as well.

# %% [markdown]
# <ins>Instructions</ins>:<br>
# - Visualize the outliers identified by overlaying them on a sales line plot.

# %% [markdown]
# <ins>Hints</ins> (click when needed):<br>
# - [Matplotlib plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
# sample one of the store category to see how our outlier detection performs
def visualize_outliers(store, category):
    # visualization of outliers detected
    plt.plot(merged[(merged['cat_id']==category) & (merged['store_id'] == store)].date,
             merged[(merged['cat_id']==category) & (merged['store_id'] == store)].dtrend,lw = .5)
    
    plt.scatter(merged[(merged['anomaly'] == True) & (merged['cat_id']==category) & (merged['store_id'] == store)].date,
                merged[(merged['anomaly'] == True) & (merged['cat_id']==category) & (merged['store_id'] == store)].dtrend,color='r')
# sample one of the store category to see how our outlier detection performs
for i in cat:
    for j in stores:
        plt.title(f'{i} in {j}')
        visualize_outliers(j, i)
        plt.show()

# %%
for i in cat:
    for j in stores:
        #print(i,j)
        print(merged[(merged['cat_id'] == i) & (merged['store_id'] == j) & (merged['anomaly'] == True)])
# Out:
#            date store_id cat_id     sales       dtrend  anomaly
# 330  2011-12-25     TX_1  FOODS      0.00 -4325.732392     True
# 434  2012-04-07     TX_1  FOODS   8212.22  3818.767400     True
# 435  2012-04-08     TX_1  FOODS   8057.01  3662.906244     True
# 442  2012-04-15     TX_1  FOODS   7137.98  2739.318154     True
# 463  2012-05-06     TX_1  FOODS   7965.78  3553.443881     True
# 533  2012-07-15     TX_1  FOODS   7625.19  3167.272972     True
# 696  2012-12-25     TX_1  FOODS      0.00 -4564.055431     True
# 960  2013-09-15     TX_1  FOODS   7578.16  2842.199426     True
# 981  2013-10-06     TX_1  FOODS   7659.31  2909.675153     True
# 988  2013-10-13     TX_1  FOODS   7472.06  2717.867062     True
# 1061 2013-12-25     TX_1  FOODS      1.58 -4800.147315     True
# 1135 2014-03-09     TX_1  FOODS   7474.15  2624.237153     True
# 1170 2014-04-13     TX_1  FOODS   8024.84  3152.136698     True
# 1177 2014-04-20     TX_1  FOODS   7802.21  2924.948607     True
# 1408 2014-12-07     TX_1  FOODS   7636.42  2608.741607     True
# 1426 2014-12-25     TX_1  FOODS      0.00 -5039.399199     True
# 1506 2015-03-15     TX_1  FOODS   7774.89  2683.398334     True
# 1527 2015-04-05     TX_1  FOODS   8014.92  2909.754061     True
# 1598 2015-06-15     TX_1  FOODS  10036.83  4885.431996     True
# 1791 2015-12-25     TX_1  FOODS      1.58 -5275.491082     True
# 1884 2016-03-27     TX_1  FOODS   7966.05  2628.421424     True
# 1933 2016-05-15     TX_1  FOODS   8567.29  3197.754788     True
#            date store_id cat_id     sales       dtrend  anomaly
# 6153 2011-12-25     TX_2  FOODS      0.00 -5962.190850     True
# 6195 2012-02-05     TX_2  FOODS   9683.29  3702.537501     True
# 6251 2012-04-01     TX_2  FOODS   9969.98  3964.478635     True
# 6257 2012-04-07     TX_2  FOODS  10122.12  4113.966971     True
# 6265 2012-04-15     TX_2  FOODS   9692.91  3681.221419     True
# 6286 2012-05-06     TX_2  FOODS  10007.18  3986.210594     True
# 6314 2012-06-03     TX_2  FOODS   9562.72  3529.376161     True
# 6320 2012-06-09     TX_2  FOODS   9507.87  3471.874497     True
# 6519 2012-12-25     TX_2  FOODS      0.00 -6123.942364     True
# 6748 2013-08-11     TX_2  FOODS   9699.05  3473.902453     True
# 6783 2013-09-15     TX_2  FOODS  10379.24  4138.624412     True
# 6811 2013-10-13     TX_2  FOODS  10039.32  3786.329979     True
# 6884 2013-12-25     TX_2  FOODS     17.08 -6268.171935     True
# 6975 2014-03-26     TX_2  FOODS   1964.22 -4361.248842     True
# 7048 2014-06-07     TX_2  FOODS   9944.85  3587.119244     True
# 7249 2014-12-25     TX_2  FOODS     12.10 -6434.461505     True
# 7338 2015-03-24     TX_2  FOODS    262.11 -6223.784524     True
# 7339 2015-03-25     TX_2  FOODS  10290.56  3804.223532     True
# 7421 2015-06-15     TX_2  FOODS  13182.89  6660.314122     True
# 7614 2015-12-25     TX_2  FOODS      0.00 -6607.871076     True
# 7756 2016-05-15     TX_2  FOODS  10298.41  3627.782872     True
#             date store_id cat_id     sales       dtrend  anomaly
# 11843 2011-08-14     TX_3  FOODS   7142.87  2789.456704     True
# 11871 2011-09-11     TX_3  FOODS   7093.06  2704.439939     True
# 11976 2011-12-25     TX_3  FOODS      3.36 -4517.285430     True
# 12018 2012-02-05     TX_3  FOODS   7822.95  3249.494423     True
# 12080 2012-04-07     TX_3  FOODS   7783.18  3131.766586     True
# 12342 2012-12-25     TX_3  FOODS      5.26 -4975.588145     True
# 12707 2013-12-25     TX_3  FOODS      1.58 -5438.213475     True
# 12816 2014-04-13     TX_3  FOODS   8456.28  2879.431618     True
# 13072 2014-12-25     TX_3  FOODS     12.90 -5885.838806     True
# 13244 2015-06-15     TX_3  FOODS  13108.76  6993.751066     True
# 13437 2015-12-25     TX_3  FOODS     11.18 -6346.504137     True
# 13481 2016-02-07     TX_3  FOODS   9209.46  2796.450947     True
# 13571 2016-05-07     TX_3  FOODS   9534.85  3008.676345     True
# 13579 2016-05-15     TX_3  FOODS   9899.04  3362.807269     True
#             date store_id cat_id     sales       dtrend  anomaly
# 17799 2011-12-25     CA_1  FOODS      0.00 -6179.663277     True
# 17903 2012-04-07     CA_1  FOODS  11148.95  4832.519329     True
# 17938 2012-05-12     CA_1  FOODS  11119.22  4756.761841     True
# 18037 2012-08-19     CA_1  FOODS  11106.77  4614.119802     True
# 18050 2012-09-01     CA_1  FOODS  11164.83  4655.083878     True
# 18165 2012-12-25     CA_1  FOODS      0.00 -6660.979298     True
# 18530 2013-12-25     CA_1  FOODS      0.00 -7140.980249     True
# 18660 2014-05-04     CA_1  FOODS  12279.28  4967.340508     True
# 18842 2014-11-02     CA_1  FOODS  12179.02  4627.737569     True
# 18895 2014-12-25     CA_1  FOODS      0.00 -7620.981199     True
# 19260 2015-12-25     CA_1  FOODS      0.00 -8100.982150     True
#             date store_id cat_id     sales       dtrend  anomaly
# 23622 2011-12-25     CA_2  FOODS     10.06 -3490.868988     True
# 23988 2012-12-25     CA_2  FOODS      3.16 -4086.460452     True
# 24353 2013-12-25     CA_2  FOODS      4.06 -4672.643470     True
# 24690 2014-11-27     CA_2  FOODS   2135.45 -3083.299983     True
# 24718 2014-12-25     CA_2  FOODS     10.18 -5253.606488     True
# ...          ...      ...    ...       ...          ...      ...
# 25218 2016-05-08     CA_2  FOODS   9475.90  3407.890199     True
# 25224 2016-05-14     CA_2  FOODS  10903.33  4825.669520     True
# 25225 2016-05-15     CA_2  FOODS  11875.34  5796.071073     True
# 25231 2016-05-21     CA_2  FOODS  12753.14  6664.220393     True
# 25232 2016-05-22     CA_2  FOODS  11552.15  5461.621947     True
#
# [74 rows x 6 columns]
#             date store_id cat_id     sales        dtrend  anomaly
# 29445 2011-12-25     CA_3  FOODS      0.82  -8470.564367     True
# 29459 2012-01-08     CA_3  FOODS  13243.67   4749.061185     True
# 29493 2012-02-11     CA_3  FOODS  13694.63   5143.618953     True
# 29515 2012-03-04     CA_3  FOODS  14217.73   5630.223391     True
# 29522 2012-03-11     CA_3  FOODS  13746.66   5147.541167     True
# 29549 2012-04-07     CA_3  FOODS  14322.84   5678.931159     True
# 29811 2012-12-25     CA_3  FOODS     10.37  -9068.167803     True
# 30176 2013-12-25     CA_3  FOODS      7.44  -9676.592351     True
# 30250 2014-03-09     CA_3  FOODS  15128.15   5321.359850     True
# 30460 2014-10-05     CA_3  FOODS  15241.97   5086.813124     True
# 30488 2014-11-02     CA_3  FOODS  15001.79   4800.184228     True
# 30541 2014-12-25     CA_3  FOODS      0.00 -10289.526898     True
# 30878 2015-11-27     CA_3  FOODS   5636.82  -5211.752549     True
# 30906 2015-12-25     CA_3  FOODS      7.96 -10887.061446     True
#             date store_id cat_id    sales       dtrend  anomaly
# 35268 2011-12-25     CA_4  FOODS     0.00 -3218.319218     True
# 35282 2012-01-08     CA_4  FOODS  4873.35  1642.117245     True
# 35309 2012-02-04     CA_4  FOODS  5270.26  2014.122566     True
# 35317 2012-02-12     CA_4  FOODS  4835.86  1572.343402     True
# 35345 2012-03-11     CA_4  FOODS  5148.28  1858.936329     True
# 35365 2012-03-31     CA_4  FOODS  4897.63  1589.838419     True
# 35366 2012-04-01     CA_4  FOODS  4865.71  1556.996023     True
# 35372 2012-04-07     CA_4  FOODS  5097.79  1783.541650     True
# 35429 2012-06-03     CA_4  FOODS  5385.18  2018.355107     True
# 35602 2012-11-23     CA_4  FOODS  1966.59 -1559.809313     True
# 35634 2012-12-25     CA_4  FOODS     0.00 -3555.915969     True
# 35673 2013-02-02     CA_4  FOODS  5552.92  1961.030607     True
# 35737 2013-04-07     CA_4  FOODS  5201.28  1550.357295     True
# 35877 2013-08-25     CA_4  FOODS  5465.20  1685.141926     True
# 35885 2013-09-02     CA_4  FOODS  5317.95  1530.512762     True
# 35891 2013-09-08     CA_4  FOODS  5709.05  1916.078390     True
# 35898 2013-09-15     CA_4  FOODS  5484.98  1685.551621     True
# 35972 2013-11-28     CA_4  FOODS  2225.59 -1642.095645     True
# 35973 2013-11-29     CA_4  FOODS  2005.05 -1863.558041     True
# 35999 2013-12-25     CA_4  FOODS     0.00 -3892.590324     True
# 36006 2014-01-01     CA_4  FOODS  2155.01 -1744.037092     True
# 36037 2014-02-01     CA_4  FOODS  5787.75  1860.108648     True
# 36073 2014-03-09     CA_4  FOODS  5564.36  1603.512410     True
# 36101 2014-04-06     CA_4  FOODS  5541.31  1554.635336     True
# 36255 2014-09-07     CA_4  FOODS  5655.81  1527.086430     True
# 36283 2014-10-05     CA_4  FOODS  6060.71  1906.159356     True
# 36297 2014-10-19     CA_4  FOODS  5814.02  1646.555819     True
# 36311 2014-11-02     CA_4  FOODS  5864.44  1684.062283     True
# 36318 2014-11-09     CA_4  FOODS  5691.72  1504.885514     True
# 36337 2014-11-28     CA_4  FOODS  2549.04 -1655.320000     True
# 36364 2014-12-25     CA_4  FOODS     0.00 -4229.264679     True
# 36700 2015-11-26     CA_4  FOODS  2751.61 -1787.579564     True
# 36701 2015-11-27     CA_4  FOODS  2246.59 -2293.521960     True
# 36729 2015-12-25     CA_4  FOODS     0.00 -4565.939033     True
# 36736 2016-01-01     CA_4  FOODS  2873.30 -1699.095802     True
# 36772 2016-02-06     CA_4  FOODS  6110.37  1504.767960     True
# 36836 2016-04-10     CA_4  FOODS  6443.83  1779.194649     True
# 36857 2016-05-01     CA_4  FOODS  6614.35  1930.344343     True
# 36871 2016-05-15     CA_4  FOODS  6380.78  1683.860807     True
# 36878 2016-05-22     CA_4  FOODS  6597.29  1893.914038     True
#             date store_id cat_id     sales       dtrend  anomaly
# 41396 2012-10-25     WI_1  FOODS    486.05 -2875.003638     True
# 41398 2012-10-27     WI_1  FOODS   6502.33  3135.181577     True
# 41405 2012-11-03     WI_1  FOODS   6525.73  3137.249832     True
# 41406 2012-11-04     WI_1  FOODS   5888.04  2496.512439     True
# 41412 2012-11-10     WI_1  FOODS   6642.36  3232.548086     True
# ...          ...      ...    ...       ...          ...      ...
# 42679 2016-04-30     WI_1  FOODS   9675.02  2404.162068     True
# 42680 2016-05-01     WI_1  FOODS  10125.82  2851.914676     True
# 42686 2016-05-07     WI_1  FOODS  10050.41  2758.220322     True
# 42693 2016-05-14     WI_1  FOODS  10511.62  3198.098576     True
# 42694 2016-05-15     WI_1  FOODS  10609.98  3293.411184     True
#
# [82 rows x 6 columns]
#             date store_id cat_id     sales       dtrend  anomaly
# 47117 2012-07-15     WI_2  FOODS   9381.05  4946.517782     True
# 47173 2012-09-09     WI_2  FOODS   9748.78  5110.042781     True
# 47280 2012-12-25     WI_2  FOODS      5.94 -5022.974632     True
# 54241 2016-02-06     WI_3  FOODS  10627.65  4932.159330     True
# 54248 2016-02-13     WI_3  FOODS   9903.62  4207.703404     True
# 54270 2016-03-06     WI_3  FOODS   9835.70  4138.444778     True
# 54298 2016-04-03     WI_3  FOODS   9811.23  4112.271072     True
# 54304 2016-04-09     WI_3  FOODS  10419.92  4720.595992     True
# 54339 2016-05-14     WI_3  FOODS  10608.35  4906.896360     True
# 54340 2016-05-15     WI_3  FOODS  11517.60  5816.085513     True
#            date store_id   cat_id    sales       dtrend  anomaly
# 2271 2011-12-25     TX_1  HOBBIES     0.00  -611.129407     True
# 2481 2012-07-22     TX_1  HOBBIES  1262.15   566.487206     True
# 2637 2012-12-25     TX_1  HOBBIES     0.00  -758.459024     True
# 2684 2013-02-10     TX_1  HOBBIES  1350.46   573.081599     True
# 2718 2013-03-16     TX_1  HOBBIES  1308.00   516.935241     True
# 2761 2013-04-28     TX_1  HOBBIES  1409.68   601.306024     True
# 2775 2013-05-12     TX_1  HOBBIES  1338.81   524.800465     True
# 3002 2013-12-25     TX_1  HOBBIES     0.00  -905.386101     True
# 3356 2014-12-14     TX_1  HOBBIES  1566.11   518.224762     True
# 3367 2014-12-25     TX_1  HOBBIES     0.00 -1052.313178     True
# 3412 2015-02-08     TX_1  HOBBIES  1744.37   673.942525     True
# 3431 2015-02-27     TX_1  HOBBIES  1698.41   620.334266     True
# 3432 2015-02-28     TX_1  HOBBIES  1737.42   658.941727     True
# 3433 2015-03-01     TX_1  HOBBIES  2150.44  1071.559187     True
# 3440 2015-03-08     TX_1  HOBBIES  1706.80   625.101407     True
# 3447 2015-03-15     TX_1  HOBBIES  1599.87   515.353627     True
# 3454 2015-03-22     TX_1  HOBBIES  1788.06   700.725848     True
# 3461 2015-03-29     TX_1  HOBBIES  1708.88   618.728068     True
# 3468 2015-04-05     TX_1  HOBBIES  1608.58   515.610289     True
# 3475 2015-04-12     TX_1  HOBBIES  1714.08   618.292509     True
# 3481 2015-04-18     TX_1  HOBBIES  1802.67   704.467270     True
# 3489 2015-04-26     TX_1  HOBBIES  1823.28   721.856950     True
# 3503 2015-05-10     TX_1  HOBBIES  1683.97   576.911391     True
# 3509 2015-05-16     TX_1  HOBBIES  1698.57   589.096151     True
# 3510 2015-05-17     TX_1  HOBBIES  2053.74   943.863611     True
# 3516 2015-05-23     TX_1  HOBBIES  1681.37   569.078372     True
# 3517 2015-05-24     TX_1  HOBBIES  1906.75   794.055832     True
# 3524 2015-05-31     TX_1  HOBBIES  1834.72   719.208052     True
# 3530 2015-06-06     TX_1  HOBBIES  1627.28   509.352813     True
# 3539 2015-06-15     TX_1  HOBBIES  1729.98   608.429953     True
# 3597 2015-08-12     TX_1  HOBBIES  1700.99   556.092637     True
# 3692 2015-11-15     TX_1  HOBBIES  1709.17   526.031343     True
# 3732 2015-12-25     TX_1  HOBBIES     0.00 -1199.240254     True
# 3733 2015-12-26     TX_1  HOBBIES  1967.92   768.277206     True
# 3776 2016-02-07     TX_1  HOBBIES  1882.70   665.747988     True
# 3790 2016-02-21     TX_1  HOBBIES  1905.58   682.992429     True
# 3797 2016-02-28     TX_1  HOBBIES  1793.26   567.854650     True
# 3853 2016-04-24     TX_1  HOBBIES  1892.40   644.452413     True
# 3874 2016-05-15     TX_1  HOBBIES  1831.87   575.469075     True
#            date store_id   cat_id    sales       dtrend  anomaly
# 8094 2011-12-25     TX_2  HOBBIES     0.00 -1048.308863     True
# 8332 2012-08-19     TX_2  HOBBIES  2071.42   891.474808     True
# 8460 2012-12-25     TX_2  HOBBIES     0.00 -1250.741201     True
# 8478 2013-01-12     TX_2  HOBBIES  2137.54   876.843110     True
# 8493 2013-01-27     TX_2  HOBBIES  2256.91   987.916703     True
# 8499 2013-02-02     TX_2  HOBBIES  2525.44  1253.128140     True
# 8521 2013-02-24     TX_2  HOBBIES  2276.51   992.030076     True
# 8527 2013-03-02     TX_2  HOBBIES  2281.85   994.051513     True
# 8534 2013-03-09     TX_2  HOBBIES  2156.11   864.439856     True
# 8584 2013-04-28     TX_2  HOBBIES  2213.04   893.715165     True
# 8597 2013-05-11     TX_2  HOBBIES  2339.49  1012.974946     True
# 8605 2013-05-19     TX_2  HOBBIES  2390.50  1059.560195     True
# 8825 2013-12-25     TX_2  HOBBIES     0.00 -1452.620445     True
# 8916 2014-03-26     TX_2  HOBBIES   546.17  -956.781983     True
# 9190 2014-12-25     TX_2  HOBBIES     0.00 -1654.499690     True
# 9249 2015-02-22     TX_2  HOBBIES  2638.58   951.447775     True
# 9256 2015-03-01     TX_2  HOBBIES  3028.94  1337.936118     True
# 9269 2015-03-14     TX_2  HOBBIES  2661.26   963.065898     True
# 9270 2015-03-15     TX_2  HOBBIES  2703.03  1004.282804     True
# 9279 2015-03-24     TX_2  HOBBIES    48.21 -1655.515040     True
# 9280 2015-03-25     TX_2  HOBBIES  2853.72  1149.441866     True
# 9284 2015-03-29     TX_2  HOBBIES  2902.62  1196.129491     True
# 9305 2015-04-19     TX_2  HOBBIES  2600.08   881.974521     True
# 9319 2015-05-03     TX_2  HOBBIES  2805.49  1079.641207     True
# 9332 2015-05-16     TX_2  HOBBIES  2770.35  1037.310987     True
# 9362 2015-06-15     TX_2  HOBBIES  2936.86  1187.228173     True
# 9555 2015-12-25     TX_2  HOBBIES     0.00 -1856.378935     True
# 9682 2016-04-30     TX_2  HOBBIES  2832.23   905.608150     True
# 9697 2016-05-15     TX_2  HOBBIES  2932.83   997.911743     True
# 9704 2016-05-22     TX_2  HOBBIES  3060.25  1121.460086     True
#             date store_id   cat_id    sales       dtrend  anomaly
# 14283 2012-12-25     TX_3  HOBBIES     0.00 -1075.175668     True
# 14621 2013-11-28     TX_3  HOBBIES   491.06  -929.037716     True
# 14648 2013-12-25     TX_3  HOBBIES     0.00 -1447.650661     True
# 14907 2014-09-10     TX_3  HOBBIES   818.07  -893.884833     True
# 14992 2014-12-04     TX_3  HOBBIES   825.65  -973.045585     True
# 15013 2014-12-25     TX_3  HOBBIES     0.00 -1820.125653     True
# 15037 2015-01-18     TX_3  HOBBIES  3295.28  1450.662841     True
# 15058 2015-02-08     TX_3  HOBBIES  2840.48   974.432773     True
# 15064 2015-02-14     TX_3  HOBBIES  2990.86  1118.689896     True
# 15065 2015-02-15     TX_3  HOBBIES  3478.14  1604.949417     True
# 15071 2015-02-21     TX_3  HOBBIES  2881.20  1001.886540     True
# 15072 2015-02-22     TX_3  HOBBIES  3062.21  1181.876061     True
# 15078 2015-02-28     TX_3  HOBBIES  2829.59   943.133184     True
# 15079 2015-03-01     TX_3  HOBBIES  3087.64  1200.162705     True
# 15080 2015-03-02     TX_3  HOBBIES  2821.63   933.132225     True
# 15088 2015-03-10     TX_3  HOBBIES  2895.60   998.938390     True
# 15093 2015-03-15     TX_3  HOBBIES  2923.14  1021.375992     True
# 15098 2015-03-20     TX_3  HOBBIES  2797.77   890.903595     True
# 15100 2015-03-22     TX_3  HOBBIES  3184.93  1276.022636     True
# 15106 2015-03-28     TX_3  HOBBIES  3121.62  1206.589760     True
# 15112 2015-04-03     TX_3  HOBBIES  2841.80   920.646883     True
# 15113 2015-04-04     TX_3  HOBBIES  3367.62  1445.446404     True
# 15119 2015-04-10     TX_3  HOBBIES  2927.52   999.223527     True
# 15121 2015-04-12     TX_3  HOBBIES  3335.01  1404.672568     True
# 15135 2015-04-26     TX_3  HOBBIES  2915.17   970.545856     True
# 15140 2015-05-01     TX_3  HOBBIES  2869.58   919.853459     True
# 15141 2015-05-02     TX_3  HOBBIES  3313.51  1362.762980     True
# 15142 2015-05-03     TX_3  HOBBIES  3667.59  1715.822500     True
# 15146 2015-05-07     TX_3  HOBBIES  2880.74   924.890583     True
# 15148 2015-05-09     TX_3  HOBBIES  3198.81  1240.919624     True
# 15155 2015-05-16     TX_3  HOBBIES  2861.01   895.976268     True
# 15156 2015-05-17     TX_3  HOBBIES  3190.29  1224.235788     True
# 15162 2015-05-23     TX_3  HOBBIES  3496.66  1524.482912     True
# 15163 2015-05-24     TX_3  HOBBIES  3177.94  1204.742432     True
# 15170 2015-05-31     TX_3  HOBBIES  3901.29  1920.949076     True
# 15171 2015-06-01     TX_3  HOBBIES  3395.18  1413.818597     True
# 15185 2015-06-15     TX_3  HOBBIES  3180.19  1184.541885     True
# 15203 2015-07-03     TX_3  HOBBIES  2868.29   854.273255     True
# 15205 2015-07-05     TX_3  HOBBIES  3006.29   990.232296     True
# 15324 2015-11-01     TX_3  HOBBIES  3147.14  1009.645244     True
# 15338 2015-11-15     TX_3  HOBBIES  3207.52  1055.738532     True
# 15344 2015-11-21     TX_3  HOBBIES  3089.33   931.425655     True
# 15359 2015-12-06     TX_3  HOBBIES  3096.65   923.438464     True
# 15378 2015-12-25     TX_3  HOBBIES     0.00 -2192.600645     True
# 15415 2016-01-31     TX_3  HOBBIES  3718.28  1487.921616     True
# 15421 2016-02-06     TX_3  HOBBIES  3465.82  1229.338739     True
# 15422 2016-02-07     TX_3  HOBBIES  3207.57   970.068260     True
# 15443 2016-02-28     TX_3  HOBBIES  3203.51   944.578192     True
# 15492 2016-04-17     TX_3  HOBBIES  3221.19   912.254699     True
# 15520 2016-05-15     TX_3  HOBBIES  3336.34   998.831275     True
# 15527 2016-05-22     TX_3  HOBBIES  3327.41   982.757919     True
#             date store_id   cat_id    sales       dtrend  anomaly
# 19740 2011-12-25     CA_1  HOBBIES     0.00 -1157.119169     True
# 20106 2012-12-25     CA_1  HOBBIES     0.00 -1445.692884     True
# 20145 2013-02-02     CA_1  HOBBIES  2643.03  1166.587458     True
# 20173 2013-03-02     CA_1  HOBBIES  2655.75  1157.230780     True
# 20370 2013-09-15     CA_1  HOBBIES  2689.93  1036.085584     True
# 20471 2013-12-25     CA_1  HOBBIES     0.00 -1733.478146     True
# 20509 2014-02-01     CA_1  HOBBIES  2794.74  1031.300648     True
# 20782 2014-11-01     CA_1  HOBBIES  3025.25  1046.563041     True
# 20808 2014-11-27     CA_1  HOBBIES   752.06 -1247.126731     True
# 20822 2014-12-11     CA_1  HOBBIES  1039.86  -970.365070     True
# 20836 2014-12-25     CA_1  HOBBIES     0.00 -2021.263409     True
# 20880 2015-02-07     CA_1  HOBBIES  3228.06  1172.104669     True
# 20901 2015-02-28     CA_1  HOBBIES  3435.87  1363.357161     True
# 20951 2015-04-19     CA_1  HOBBIES  3057.10   945.164522     True
# 20986 2015-05-24     CA_1  HOBBIES  3157.18  1017.648675     True
# 21026 2015-07-03     CA_1  HOBBIES  3250.93  1079.860564     True
# 21055 2015-08-01     CA_1  HOBBIES  3145.55   951.615434     True
# 21056 2015-08-02     CA_1  HOBBIES  3395.08  1200.356981     True
# 21062 2015-08-08     CA_1  HOBBIES  3224.46  1025.006265     True
# 21069 2015-08-15     CA_1  HOBBIES  3389.52  1184.547095     True
# 21119 2015-10-04     CA_1  HOBBIES  3191.69   947.294456     True
# 21146 2015-10-31     CA_1  HOBBIES  3204.24   938.556232     True
# 21161 2015-11-15     CA_1  HOBBIES  3462.96  1185.449440     True
# 21168 2015-11-22     CA_1  HOBBIES  3321.31  1038.280271     True
# 21172 2015-11-26     CA_1  HOBBIES   941.95 -1344.233541     True
# 21188 2015-12-12     CA_1  HOBBIES  3666.65  1367.851215     True
# 21195 2015-12-19     CA_1  HOBBIES  3985.27  1680.952046     True
# 21196 2015-12-20     CA_1  HOBBIES  3293.67   988.563593     True
# 21201 2015-12-25     CA_1  HOBBIES     0.00 -2309.048671     True
# 21209 2016-01-02     CA_1  HOBBIES  3692.66  1377.303707     True
# 21273 2016-03-06     CA_1  HOBBIES  3805.72  1439.902729     True
# 21342 2016-05-14     CA_1  HOBBIES  3379.01   958.789488     True
#             date store_id   cat_id    sales       dtrend  anomaly
# 25563 2011-12-25     CA_2  HOBBIES     0.00  -907.870368     True
# 25929 2012-12-25     CA_2  HOBBIES     0.00 -1039.819457     True
# 25968 2013-02-02     CA_2  HOBBIES  1844.26   790.380394     True
# 25989 2013-02-23     CA_2  HOBBIES  1904.31   842.859545     True
# 25996 2013-03-02     CA_2  HOBBIES  1887.45   823.475929     True
# 26017 2013-03-23     CA_2  HOBBIES  1789.43   717.885079     True
# 26267 2013-11-28     CA_2  HOBBIES   383.41  -778.264080     True
# 26294 2013-12-25     CA_2  HOBBIES     0.00 -1171.408029     True
# 31855 2013-04-07     CA_3  HOBBIES  2591.15   946.384680     True
# 31889 2013-05-11     CA_3  HOBBIES  2490.94   819.076310     True
# 31910 2013-06-01     CA_3  HOBBIES  2565.49   876.889081     True
# 31918 2013-06-09     CA_3  HOBBIES  2571.64   876.662994     True
# 31974 2013-08-04     CA_3  HOBBIES  2649.09   909.480383     True
# 32090 2013-11-28     CA_3  HOBBIES   864.15  -967.912881     True
# 32117 2013-12-25     CA_3  HOBBIES     0.00 -1853.582175     True
# 32128 2014-01-05     CA_3  HOBBIES  2834.43   972.080705     True
# 32454 2014-11-27     CA_3  HOBBIES  1004.44 -1117.734848     True
# 32468 2014-12-11     CA_3  HOBBIES  1278.08  -855.253000     True
# 32482 2014-12-25     CA_3  HOBBIES     0.00 -2144.491153     True
# 32526 2015-02-07     CA_3  HOBBIES  2997.35   817.790368     True
# 32555 2015-03-08     CA_3  HOBBIES  3138.17   935.497052     True
# 32562 2015-03-15     CA_3  HOBBIES  3205.44   997.187975     True
# 32576 2015-03-29     CA_3  HOBBIES  3107.31   887.899823     True
# 32597 2015-04-19     CA_3  HOBBIES  3110.47   874.322594     True
# 32633 2015-05-25     CA_3  HOBBIES  3299.58  1034.740202     True
# 32672 2015-07-03     CA_3  HOBBIES  3294.24   998.316777     True
# 32701 2015-08-01     CA_3  HOBBIES  3141.16   822.123460     True
# 32779 2015-10-18     CA_3  HOBBIES  3314.63   933.426610     True
# 32800 2015-11-08     CA_3  HOBBIES  3259.09   861.149382     True
# 32818 2015-11-26     CA_3  HOBBIES  1149.40 -1262.886815     True
# 32819 2015-11-27     CA_3  HOBBIES  1509.83  -903.253825     True
# 32847 2015-12-25     CA_3  HOBBIES     0.00 -2435.400131     True
# 32884 2016-01-31     CA_3  HOBBIES  3480.53  1015.640466     True
# 32933 2016-03-20     CA_3  HOBBIES  3485.50   981.556932     True
# 32968 2016-04-24     CA_3  HOBBIES  3355.61   823.771551     True
# 32974 2016-04-30     CA_3  HOBBIES  3371.03   834.409485     True
#             date store_id   cat_id    sales       dtrend  anomaly
# 37209 2011-12-25     CA_4  HOBBIES     0.00  -642.130721     True
# 37575 2012-12-25     CA_4  HOBBIES     0.00  -838.316471     True
# 37641 2013-03-01     CA_4  HOBBIES  1312.92   439.225771     True
# 37643 2013-03-03     CA_4  HOBBIES  1297.34   422.573718     True
# 37670 2013-03-30     CA_4  HOBBIES  1437.27   548.030999     True
# 37733 2013-06-01     CA_4  HOBBIES  1508.97   585.961321     True
# 37766 2013-07-04     CA_4  HOBBIES   503.89  -436.807558     True
# 37796 2013-08-03     CA_4  HOBBIES  1342.85   386.071643     True
# 37878 2013-10-24     CA_4  HOBBIES  1418.05   417.317458     True
# 37895 2013-11-10     CA_4  HOBBIES  1399.54   389.695005     True
# 37913 2013-11-28     CA_4  HOBBIES   563.22  -456.273474     True
# 37940 2013-12-25     CA_4  HOBBIES     0.00 -1033.966193     True
# 37978 2014-02-01     CA_4  HOBBIES  1624.80   570.464795     True
# 37985 2014-02-08     CA_4  HOBBIES  1463.52   405.432608     True
# 38032 2014-03-27     CA_4  HOBBIES   681.29  -401.990644     True
# 38066 2014-04-30     CA_4  HOBBIES   626.63  -474.875550     True
# 38277 2014-11-27     CA_4  HOBBIES   557.68  -656.927170     True
# 38278 2014-11-28     CA_4  HOBBIES   812.69  -402.453197     True
# 38291 2014-12-11     CA_4  HOBBIES   561.10  -661.011543     True
# 38300 2014-12-20     CA_4  HOBBIES  1631.06   404.124217     True
# 38305 2014-12-25     CA_4  HOBBIES     0.00 -1229.615916     True
# 38312 2015-01-01     CA_4  HOBBIES   828.39  -404.978102     True
# 38342 2015-01-31     CA_4  HOBBIES  1677.19   427.741099     True
# 38371 2015-03-01     CA_4  HOBBIES  1816.31   551.316326     True
# 38391 2015-03-21     CA_4  HOBBIES  1663.99   388.275793     True
# 38456 2015-05-25     CA_4  HOBBIES  1716.16   405.604062     True
# 38463 2015-06-01     CA_4  HOBBIES  1933.85   619.541875     True
# 38509 2015-07-17     CA_4  HOBBIES  1743.94   404.974650     True
# 38514 2015-07-22     CA_4  HOBBIES   948.49  -393.155483     True
# 38524 2015-08-01     CA_4  HOBBIES  1816.49   469.484251     True
# 38579 2015-09-25     CA_4  HOBBIES   952.47  -424.017214     True
# 38587 2015-10-03     CA_4  HOBBIES  1877.87   497.094572     True
# 38618 2015-11-03     CA_4  HOBBIES  1913.14   515.747747     True
# 38630 2015-11-15     CA_4  HOBBIES  1812.37   408.545427     True
# 38632 2015-11-17     CA_4  HOBBIES  2039.23   634.333374     True
# 38641 2015-11-26     CA_4  HOBBIES   687.36  -722.360866     True
# 38664 2015-12-19     CA_4  HOBBIES  1969.18   547.130521     True
# 38670 2015-12-25     CA_4  HOBBIES     0.00 -1425.265638     True
# 38677 2016-01-01     CA_4  HOBBIES   965.74  -463.277825     True
# 38753 2016-03-17     CA_4  HOBBIES  1061.78  -407.975849     True
# 38779 2016-04-12     CA_4  HOBBIES   892.53  -591.162542     True
# 38780 2016-04-13     CA_4  HOBBIES  1085.94  -398.288569     True
#             date store_id   cat_id    sales       dtrend  anomaly
# 42709 2011-02-05     WI_1  HOBBIES  1599.73   807.983810     True
# 43032 2011-12-25     WI_1  HOBBIES     0.00  -936.731865     True
# 43334 2012-10-22     WI_1  HOBBIES   201.15  -871.141228     True
# 43335 2012-10-23     WI_1  HOBBIES   195.12  -877.620100     True
# 43337 2012-10-25     WI_1  HOBBIES   113.48  -960.157844     True
# 43338 2012-10-26     WI_1  HOBBIES  1984.26   910.173284     True
# 43339 2012-10-27     WI_1  HOBBIES  2158.74  1084.204412     True
# 43346 2012-11-03     WI_1  HOBBIES  1945.13   867.452307     True
# 43398 2012-12-25     WI_1  HOBBIES     0.00 -1101.019040     True
# 43423 2013-01-19     WI_1  HOBBIES  1932.42   820.179159     True
# 43437 2013-02-02     WI_1  HOBBIES  1945.49   826.964950     True
# 43465 2013-03-02     WI_1  HOBBIES  2207.96  1076.866532     True
# 43486 2013-03-23     WI_1  HOBBIES  1994.25   853.730219     True
# 43507 2013-04-13     WI_1  HOBBIES  2101.69   951.743906     True
# 43556 2013-06-01     WI_1  HOBBIES  1972.41   800.469175     True
True
#             date store_id   cat_id    sales       dtrend  anomaly
# 48855 2011-12-25     WI_2  HOBBIES     0.00  -491.164107     True
# 49043 2012-06-30     WI_2  HOBBIES  1053.82   487.777672     True
# 49169 2012-11-03     WI_2  HOBBIES  1067.65   451.423331     True
# 49221 2012-12-25     WI_2  HOBBIES     0.00  -636.937666     True
# 49259 2013-02-01     WI_2  HOBBIES  1188.50   536.427374     True
# 49260 2013-02-02     WI_2  HOBBIES  1282.78   630.309086     True
# 49267 2013-02-09     WI_2  HOBBIES  1166.66   511.401067     True
# 49274 2013-02-16     WI_2  HOBBIES  1129.46   471.413048     True
# 49287 2013-03-01     WI_2  HOBBIES  1110.42   447.195299     True
# 49288 2013-03-02     WI_2  HOBBIES  1274.07   610.447010     True
# 49295 2013-03-09     WI_2  HOBBIES  1115.42   449.008991     True
# 49330 2013-04-13     WI_2  HOBBIES  1118.89   438.538897     True
# 49408 2013-06-30     WI_2  HOBBIES  1244.62   533.202401     True
# 49469 2013-08-30     WI_2  HOBBIES  1225.49   489.776807     True
# 49498 2013-09-28     WI_2  HOBBIES  1195.92   448.656443     True
# 49501 2013-10-01     WI_2  HOBBIES  1205.63   457.171578     True
# 49532 2013-11-01     WI_2  HOBBIES  1300.51   539.704637     True
# 49559 2013-11-28     WI_2  HOBBIES   313.59  -457.969150     True
# 49582 2013-12-21     WI_2  HOBBIES  1381.33   600.610217     True
# 49586 2013-12-25     WI_2  HOBBIES     0.00  -782.312937     True
# 49596 2014-01-04     WI_2  HOBBIES  1251.52   465.224179     True
# 49603 2014-01-11     WI_2  HOBBIES  1306.06   516.976160     True
# 49742 2014-05-30     WI_2  HOBBIES  1310.05   465.604070     True
# 49774 2014-07-01     WI_2  HOBBIES  1324.58   467.388841     True
# 49805 2014-08-01     WI_2  HOBBIES  1360.37   490.831900     True
# 49866 2014-10-01     WI_2  HOBBIES  1375.92   482.086307     True
# 49896 2014-10-31     WI_2  HOBBIES  1468.61   562.827655     True
# 49897 2014-11-01     WI_2  HOBBIES  1406.40   500.219366     True
# 49923 2014-11-27     WI_2  HOBBIES   412.14  -504.396132     True
# 49951 2014-12-25     WI_2  HOBBIES     0.00  -927.688208     True
# 49957 2014-12-31     WI_2  HOBBIES  1385.76   455.682062     True
# 49988 2015-01-31     WI_2  HOBBIES  1411.52   469.095121     True
# 49989 2015-02-01     WI_2  HOBBIES   433.75  -509.073168     True
# 50087 2015-05-10     WI_2  HOBBIES   488.87  -492.985432     True
# 50281 2015-11-20     WI_2  HOBBIES  1536.24   477.116615     True
# 50287 2015-11-26     WI_2  HOBBIES   340.97  -720.543115     True
# 50292 2015-12-01     WI_2  HOBBIES  1553.70   490.195443     True
# 50316 2015-12-25     WI_2  HOBBIES     0.00 -1073.063479     True
# 50333 2016-01-11     WI_2  HOBBIES   625.75  -454.084382     True
# 50354 2016-02-01     WI_2  HOBBIES  1594.39   506.191561     True
# 50385 2016-03-03     WI_2  HOBBIES  1580.24   479.694620     True
# 50414 2016-04-01     WI_2  HOBBIES  1749.84   637.744256     True
# 50422 2016-04-09     WI_2  HOBBIES  1652.72   537.437949     True
#             date store_id   cat_id    sales       dtrend  anomaly
# 54352 2011-02-02     WI_3  HOBBIES   214.79  -583.103933     True
# 54501 2011-07-01     WI_3  HOBBIES  1411.11   604.748475     True
# 54678 2011-12-25     WI_3  HOBBIES     0.00  -816.420342     True
# 54679 2011-12-26     WI_3  HOBBIES  1588.94   772.462829     True
# 54719 2012-02-04     WI_3  HOBBIES  1403.82   585.069650     True
# 54837 2012-06-01     WI_3  HOBBIES  1541.90   716.443772     True
# 54928 2012-08-31     WI_3  HOBBIES  1506.98   676.352289     True
# 54957 2012-09-29     WI_3  HOBBIES  1423.35   591.074235     True
# 54959 2012-10-01     WI_3  HOBBIES  1466.38   633.990576     True
# 54964 2012-10-06     WI_3  HOBBIES  1470.38   637.706428     True
# 54991 2012-11-02     WI_3  HOBBIES  1757.52   923.312033     True
# 55019 2012-11-30     WI_3  HOBBIES  1567.36   731.560807     True
# 55034 2012-12-15     WI_3  HOBBIES  1438.21   601.558365     True
# 55044 2012-12-25     WI_3  HOBBIES     0.00  -837.219930     True
# 55082 2013-02-01     WI_3  HOBBIES  1940.58  1101.200550     True
# 55090 2013-02-09     WI_3  HOBBIES  1402.39   562.555915     True
# 55110 2013-03-01     WI_3  HOBBIES  1712.15   871.179325     True
# 55111 2013-03-02     WI_3  HOBBIES  1643.25   802.222496     True
# 55264 2013-08-02     WI_3  HOBBIES  1427.57   577.847586     True
# 55409 2013-12-25     WI_3  HOBBIES     0.00  -857.962688     True
# 55774 2014-12-25     WI_3  HOBBIES     0.00  -878.705446     True
# 55782 2015-01-02     WI_3  HOBBIES  1472.94   593.779918     True
# 55964 2015-07-03     WI_3  HOBBIES  1567.76   678.256954     True
# 56056 2015-10-03     WI_3  HOBBIES  1530.65   635.918642     True
# 56083 2015-10-30     WI_3  HOBBIES  1545.62   649.354247     True
# 56139 2015-12-25     WI_3  HOBBIES     0.00  -899.448204     True
# 56189 2016-02-13     WI_3  HOBBIES  1452.73   550.440322     True
# 56196 2016-02-20     WI_3  HOBBIES  1545.65   642.962516     True
# 56237 2016-04-01     WI_3  HOBBIES  1467.45   562.432508     True
# 56273 2016-05-07     WI_3  HOBBIES  1596.04   688.976646     True
#            date store_id     cat_id    sales       dtrend  anomaly
# 4212 2011-12-25     TX_1  HOUSEHOLD     0.00 -1951.193268     True
# 4477 2012-09-15     TX_1  HOUSEHOLD  3740.51  1499.476564     True
# 4485 2012-09-23     TX_1  HOUSEHOLD  3686.62  1436.836672     True
# 4527 2012-11-04     TX_1  HOUSEHOLD  3772.97  1477.249740     True
# 4578 2012-12-25     TX_1  HOUSEHOLD     0.00 -2351.500820     True
# 4632 2013-02-17     TX_1  HOUSEHOLD  4013.29  1602.727410     True
# 4639 2013-02-24     TX_1  HOUSEHOLD  3992.05  1573.831254     True
# 10546 2013-05-19     TX_2  HOUSEHOLD  4800.00  1791.005121     True
# 10559 2013-06-01     TX_2  HOUSEHOLD  5008.83  1988.979469     True
# 10560 2013-06-02     TX_2  HOUSEHOLD  4767.97  1747.284419     True
# 10609 2013-07-21     TX_2  HOUSEHOLD  4812.56  1750.956962     True
# 10766 2013-12-25     TX_2  HOUSEHOLD     0.00 -3192.705910     True
# 10857 2014-03-26     TX_2  HOUSEHOLD  1056.57 -2212.125473     True
# 11131 2014-12-25     TX_2  HOUSEHOLD     0.00 -3497.499211     True
# 11189 2015-02-21     TX_2  HOUSEHOLD  5295.49  1749.557880     True
# 11197 2015-03-01     TX_2  HOUSEHOLD  5348.95  1796.337479     True
# 11220 2015-03-24     TX_2  HOUSEHOLD   147.23 -3424.588674     True
# 11221 2015-03-25     TX_2  HOUSEHOLD  6283.19  2710.536276     True
# 11496 2015-12-25     TX_2  HOUSEHOLD     0.00 -3802.292513     True
# 11546 2016-02-13     TX_2  HOUSEHOLD  5873.96  2029.914980     True
# 11553 2016-02-20     TX_2  HOUSEHOLD  5732.84  1882.949629     True
# 11554 2016-02-21     TX_2  HOUSEHOLD  6381.92  2531.194579     True
# 11561 2016-02-28     TX_2  HOUSEHOLD  6096.99  2240.419228     True
# 11568 2016-03-06     TX_2  HOUSEHOLD  5802.83  1940.413877     True
# 11638 2016-05-15     TX_2  HOUSEHOLD  5814.10  1893.230367     True
# 11645 2016-05-22     TX_2  HOUSEHOLD  5838.91  1912.195016     True
#             date store_id     cat_id    sales       dtrend  anomaly
# 15858 2011-12-25     TX_3  HOUSEHOLD     0.00 -1847.268456     True
# 16109 2012-09-01     TX_3  HOUSEHOLD  3854.88  1676.532769     True
# 16123 2012-09-15     TX_3  HOUSEHOLD  3792.13  1595.316224     True
# 16137 2012-09-29     TX_3  HOUSEHOLD  3607.56  1392.279679     True
# 16224 2012-12-25     TX_3  HOUSEHOLD     0.00 -2330.036709     True
# 16382 2013-06-01     TX_3  HOUSEHOLD  3923.31  1384.865138     True
# 16589 2013-12-25     TX_3  HOUSEHOLD     0.00 -2811.485923     True
# 16623 2014-01-28     TX_3  HOUSEHOLD  1173.88 -1682.453248     True
# 16635 2014-02-09     TX_3  HOUSEHOLD  4399.97  1527.808285     True
# 16648 2014-02-22     TX_3  HOUSEHOLD  4324.45  1435.140779     True
# 16649 2014-02-23     TX_3  HOUSEHOLD  4391.95  1501.321740     True
# 16670 2014-03-16     TX_3  HOUSEHOLD  4399.91  1481.581922     True
# 16858 2014-09-20     TX_3  HOUSEHOLD  4609.05  1442.742601     True
# 16926 2014-11-27     TX_3  HOUSEHOLD  1275.91 -1980.092047     True
# 16954 2014-12-25     TX_3  HOUSEHOLD     0.00 -3292.935138     True
# 16982 2015-01-22     TX_3  HOUSEHOLD  1920.94 -1408.928228     True
# 17012 2015-02-21     TX_3  HOUSEHOLD  4932.23  1562.790604     True
# 17020 2015-03-01     TX_3  HOUSEHOLD  5012.41  1632.418292     True
# 17062 2015-04-12     TX_3  HOUSEHOLD  4873.52  1438.128657     True
# 17068 2015-04-18     TX_3  HOUSEHOLD  4956.16  1512.854423     True
# 17096 2015-05-16     TX_3  HOUSEHOLD  4910.50  1430.261333     True
# 17180 2015-08-08     TX_3  HOUSEHOLD  5070.42  1479.382061     True
# 17194 2015-08-22     TX_3  HOUSEHOLD  5336.68  1727.175516     True
# 17195 2015-08-23     TX_3  HOUSEHOLD  5079.79  1468.966477     True
# 17202 2015-08-30     TX_3  HOUSEHOLD  5038.49  1418.433205     True
# 17236 2015-10-03     TX_3  HOUSEHOLD  5404.45  1739.545881     True
# 17247 2015-10-14     TX_3  HOUSEHOLD  2008.99 -1670.423548     True
# 17279 2015-11-15     TX_3  HOUSEHOLD  5228.34  1506.717206     True
# 17290 2015-11-26     TX_3  HOUSEHOLD  1857.53 -1878.602222     True
# 17319 2015-12-25     TX_3  HOUSEHOLD     0.00 -3774.384352     True
# 17369 2016-02-13     TX_3  HOUSEHOLD  5350.81  1510.473701     True
# 17461 2016-05-15     TX_3  HOUSEHOLD  5342.76  1381.072119     True
#             date store_id     cat_id    sales       dtrend  anomaly
# 21681 2011-12-25     CA_1  HOUSEHOLD     0.00 -2388.731021     True
# 22047 2012-12-25     CA_1  HOUSEHOLD     0.00 -2820.062256     True
# 22178 2013-05-05     CA_1  HOUSEHOLD  5184.93  2210.484160     True
# 22412 2013-12-25     CA_1  HOUSEHOLD     0.00 -3250.214991     True
# 22654 2014-08-24     CA_1  HOUSEHOLD  5843.51  2308.097854     True
# 22696 2014-10-05     CA_1  HOUSEHOLD  5831.63  2246.720827     True
# 22777 2014-12-25     CA_1  HOUSEHOLD     0.00 -3680.367725     True
# 22906 2015-05-03     CA_1  HOUSEHOLD  6392.90  2560.505692     True
# 22997 2015-08-02     CA_1  HOUSEHOLD  6563.38  2623.742133     True
# 23011 2015-08-16     CA_1  HOUSEHOLD  6311.99  2355.853124     True
# 23018 2015-08-23     CA_1  HOUSEHOLD  6243.36  2278.973620     True
# 23025 2015-08-30     CA_1  HOUSEHOLD  6244.77  2272.134115     True
# 23074 2015-10-18     CA_1  HOUSEHOLD  6509.20  2478.817584     True
# 23102 2015-11-15     CA_1  HOUSEHOLD  6265.31  2201.929566     True
# 23113 2015-11-26     CA_1  HOUSEHOLD  1684.33 -2392.013941     True
# 23142 2015-12-25     CA_1  HOUSEHOLD     0.00 -4110.520460     True
# 23214 2016-03-06     CA_1  HOUSEHOLD  6603.99  2408.617494     True
#             date store_id     cat_id    sales       dtrend  anomaly
# 27504 2011-12-25     CA_2  HOUSEHOLD     0.00 -2971.435006     True
# 27870 2012-12-25     CA_2  HOUSEHOLD     0.00 -3288.824035     True
# 28235 2013-12-25     CA_2  HOUSEHOLD     0.00 -3605.345881     True
# 28301 2014-03-01     CA_2  HOUSEHOLD  6968.45  3305.870032     True
# 28600 2014-12-25     CA_2  HOUSEHOLD     0.00 -3921.867727     True
# 28819 2015-08-01     CA_2  HOUSEHOLD  7132.50  3020.719165     True
# 34888 2016-04-03     CA_3  HOUSEHOLD  10451.34  3100.458411     True
# 34895 2016-04-10     CA_3  HOUSEHOLD  10802.54  3437.837270     True
# 34909 2016-04-24     CA_3  HOUSEHOLD  10263.68  2871.334986     True
# 34930 2016-05-15     CA_3  HOUSEHOLD  10372.02  2938.211560     True
# 34937 2016-05-22     CA_3  HOUSEHOLD  10632.29  3184.660418     True
#
# [61 rows x 6 columns]
#             date store_id     cat_id    sales       dtrend  anomaly
# 39150 2011-12-25     CA_4  HOUSEHOLD     0.00 -1198.591451     True
# 39388 2012-08-19     CA_4  HOUSEHOLD  2099.05   740.592812     True
# 39483 2012-11-22     CA_4  HOUSEHOLD   765.54  -656.729142     True
# 39516 2012-12-25     CA_4  HOUSEHOLD     0.00 -1444.435400     True
# 39555 2013-02-02     CA_4  HOUSEHOLD  2125.28   654.648114     True
# 39567 2013-02-14     CA_4  HOUSEHOLD   796.38  -682.312344     True
# 39675 2013-06-02     CA_4  HOUSEHOLD  2521.99   970.753540     True
# 39752 2013-08-18     CA_4  HOUSEHOLD  2260.55   657.592273     True
# 39765 2013-08-31     CA_4  HOUSEHOLD  2350.31   738.620110     True
# 39780 2013-09-15     CA_4  HOUSEHOLD  2390.57   768.804539     True
# 39801 2013-10-06     CA_4  HOUSEHOLD  2330.00   694.128738     True
# 39854 2013-11-28     CA_4  HOUSEHOLD   834.86  -836.611615     True
# 39881 2013-12-25     CA_4  HOUSEHOLD     0.00 -1689.607644     True
# 39888 2014-01-01     CA_4  HOUSEHOLD   976.01  -718.299577     True
# 39976 2014-03-30     CA_4  HOUSEHOLD  2410.87   657.450402     True
# 39983 2014-04-06     CA_4  HOUSEHOLD  2434.60   676.478469     True
# 39996 2014-04-19     CA_4  HOUSEHOLD  2426.47   659.616307     True
# 40004 2014-04-27     CA_4  HOUSEHOLD  2437.09   664.862668     True
# 40025 2014-05-18     CA_4  HOUSEHOLD  2639.53   853.196868     True
# 40039 2014-06-01     CA_4  HOUSEHOLD  2517.58   721.843001     True
# 40046 2014-06-08     CA_4  HOUSEHOLD  2441.27   640.831068     True
# 40074 2014-07-06     CA_4  HOUSEHOLD  2470.45   651.203334     True
# 40102 2014-08-03     CA_4  HOUSEHOLD  2478.31   640.255600     True
# 40123 2014-08-24     CA_4  HOUSEHOLD  2557.18   705.019800     True
# 40185 2014-10-25     CA_4  HOUSEHOLD  2590.27   696.464104     True
# 40193 2014-11-02     CA_4  HOUSEHOLD  2607.20   708.020465     True
# 40218 2014-11-27     CA_4  HOUSEHOLD  1133.04  -782.932154     True
# 40232 2014-12-11     CA_4  HOUSEHOLD  1153.74  -771.636021     True
# 40246 2014-12-25     CA_4  HOUSEHOLD     0.00 -1934.779888     True
# 40305 2015-02-22     CA_4  HOUSEHOLD  2678.34   703.929530     True
# 40354 2015-04-12     CA_4  HOUSEHOLD  2675.69   668.365996     True
# 40403 2015-05-31     CA_4  HOUSEHOLD  2791.47   751.232462     True
# 40473 2015-08-09     CA_4  HOUSEHOLD  2974.37   887.113128     True
# 40494 2015-08-30     CA_4  HOUSEHOLD  2917.20   815.837327     True
# 40571 2015-11-15     CA_4  HOUSEHOLD  2865.96   712.876059     True
# 40582 2015-11-26     CA_4  HOUSEHOLD  1185.43  -975.042693     True
# 40583 2015-11-27     CA_4  HOUSEHOLD  1265.88  -895.264398     True
# 40611 2015-12-25     CA_4  HOUSEHOLD     0.00 -2179.952132     True
# 40631 2016-01-14     CA_4  HOUSEHOLD  1440.85  -752.536227     True
# 40669 2016-02-21     CA_4  HOUSEHOLD  2861.55   642.638991     True
# 40676 2016-02-28     CA_4  HOUSEHOLD  2890.93   667.317058     True
# 40683 2016-03-06     CA_4  HOUSEHOLD  3188.18   959.865124     True
# 40697 2016-03-20     CA_4  HOUSEHOLD  2977.59   739.871257     True
# 40710 2016-04-02     CA_4  HOUSEHOLD  2999.99   753.539095     True
# 40711 2016-04-03     CA_4  HOUSEHOLD  3240.59   993.467390     True
# 40718 2016-04-10     CA_4  HOUSEHOLD  2962.06   710.235457     True
# 40725 2016-04-17     CA_4  HOUSEHOLD  3149.28   892.753524     True
# 40732 2016-04-24     CA_4  HOUSEHOLD  3426.90  1165.671590     True
# 40739 2016-05-01     CA_4  HOUSEHOLD  2937.83   671.899657     True
# 40752 2016-05-14     CA_4  HOUSEHOLD  2933.90   659.237495     True
# 40753 2016-05-15     CA_4  HOUSEHOLD  3083.82   808.485790     True
# 40759 2016-05-21     CA_4  HOUSEHOLD  2999.68   720.315561     True
# 40760 2016-05-22     CA_4  HOUSEHOLD  3499.97  1219.933856     True
#             date store_id     cat_id    sales       dtrend  anomaly
# 44973 2011-12-25     WI_1  HOUSEHOLD     0.00 -1691.669499     True
# 45035 2012-02-25     WI_1  HOUSEHOLD  3225.32  1486.596816     True
# 45278 2012-10-25     WI_1  HOUSEHOLD   229.14 -1694.003269     True
# 45279 2012-10-26     WI_1  HOUSEHOLD  3951.18  2027.277800     True
# 45280 2012-10-27     WI_1  HOUSEHOLD  3980.06  2055.398870     True
# 45286 2012-11-02     WI_1  HOUSEHOLD  3376.06  1446.845288     True
# 45287 2012-11-03     WI_1  HOUSEHOLD  4217.15  2287.176357     True
# 45301 2012-11-17     WI_1  HOUSEHOLD  3442.97  1502.371332     True
# 45339 2012-12-25     WI_1  HOUSEHOLD     0.00 -1969.438023     True
# 45350 2013-01-05     WI_1  HOUSEHOLD  3402.53  1424.743742     True
# 45364 2013-01-19     WI_1  HOUSEHOLD  3598.37  1609.958717     True
# 45392 2013-02-16     WI_1  HOUSEHOLD  3602.79  1593.128666     True
# 45406 2013-03-02     WI_1  HOUSEHOLD  3975.54  1955.253640     True
# 45677 2013-11-28     WI_1  HOUSEHOLD   560.18 -1665.776496     True
# 45704 2013-12-25     WI_1  HOUSEHOLD     0.00 -2246.447617     True
# 45763 2014-02-22     WI_1  HOUSEHOLD  3961.14  1669.915490     True
# 46015 2014-11-01     WI_1  HOUSEHOLD  4007.49  1525.015031     True
# 46041 2014-11-27     WI_1  HOUSEHOLD   832.56 -1669.647159     True
# 52314 2016-02-20     WI_2  HOUSEHOLD  5552.99  1827.173716     True
# 52326 2016-03-03     WI_2  HOUSEHOLD  5346.51  1604.861688     True
# 52355 2016-04-01     WI_2  HOUSEHOLD  6840.70  3060.790953     True
# 52356 2016-04-02     WI_2  HOUSEHOLD  5748.77  1967.541618     True
# 52383 2016-04-29     WI_2  HOUSEHOLD  5787.51  1970.659555     True
#
# [64 rows x 6 columns]
#             date store_id     cat_id    sales       dtrend  anomaly
# 56619 2011-12-25     WI_3  HOUSEHOLD     0.00 -2244.693915     True
# 56778 2012-06-01     WI_3  HOUSEHOLD  4231.17  1949.997445     True
# 56869 2012-08-31     WI_3  HOUSEHOLD  4528.17  2226.119733     True
# 56870 2012-09-01     WI_3  HOUSEHOLD  4514.60  2212.320307     True
# 56877 2012-09-08     WI_3  HOUSEHOLD  4035.97  1732.084330     True
# 56898 2012-09-29     WI_3  HOUSEHOLD  4269.63  1960.926396     True
# 56934 2012-11-04     WI_3  HOUSEHOLD  4028.74  1711.777081     True
# 56985 2012-12-25     WI_3  HOUSEHOLD     0.00 -2328.663615     True
# 57023 2013-02-01     WI_3  HOUSEHOLD  4407.28  2069.898220     True
# 57024 2013-02-02     WI_3  HOUSEHOLD  4418.40  2080.788794     True
# 57031 2013-02-09     WI_3  HOUSEHOLD  3961.44  1622.222816     True
# 57032 2013-02-10     WI_3  HOUSEHOLD  4007.22  1667.773391     True
# 57038 2013-02-16     WI_3  HOUSEHOLD  4235.92  1895.096838     True
# 57051 2013-03-01     WI_3  HOUSEHOLD  4714.59  2370.784308     True
# 57052 2013-03-02     WI_3  HOUSEHOLD  4459.39  2115.354883     True
# 57053 2013-03-03     WI_3  HOUSEHOLD  4232.24  1887.975457     True
# 57350 2013-12-25     WI_3  HOUSEHOLD     0.00 -2412.403890     True
# 57715 2014-12-25     WI_3  HOUSEHOLD     0.00 -2496.144164     True
# 57752 2015-01-31     WI_3  HOUSEHOLD  4260.23  1755.597095     True
# 57780 2015-02-28     WI_3  HOUSEHOLD  4464.73  1953.673184     True
# 58039 2015-11-14     WI_3  HOUSEHOLD  4230.68  1660.202003     True
# 58080 2015-12-25     WI_3  HOUSEHOLD     0.00 -2579.884439     True
# 58116 2016-01-30     WI_3  HOUSEHOLD  4195.64  1607.496246     True
# 58130 2016-02-13     WI_3  HOUSEHOLD  4601.71  2010.354290     True
# 58137 2016-02-20     WI_3  HOUSEHOLD  4428.43  1835.468312     True
# 58145 2016-02-28     WI_3  HOUSEHOLD  4226.09  1631.292909     True
# 58152 2016-03-06     WI_3  HOUSEHOLD  4220.48  1624.076931     True
# 58178 2016-04-01     WI_3  HOUSEHOLD  4256.42  1654.051871     True
# 58180 2016-04-03     WI_3  HOUSEHOLD  4281.67  1678.843020     True

# %% [markdown]
# We can unmark some of the points as outliers.

# %% [markdown]
# <ins>Instructions</ins>:<br>
# - If any of the "outliers" identified are incorrect, unmark them in your `anomaly` column.

# %%
# unmark points as outliers
# take anything marked as anomaly and sales > 10 (e.g. not christmas, and unset anomaly
merged.loc[(merged['anomaly'] == True) & (abs(merged['sales']) > 10),'anomaly'] = False

# %%
merged[merged.anomaly == True]
# Out:
#             date store_id     cat_id  sales       dtrend  anomaly
# 330   2011-12-25     TX_1      FOODS   0.00 -4325.732392     True
# 696   2012-12-25     TX_1      FOODS   0.00 -4564.055431     True
# 1061  2013-12-25     TX_1      FOODS   1.58 -4800.147315     True
# 1426  2014-12-25     TX_1      FOODS   0.00 -5039.399199     True
# 1791  2015-12-25     TX_1      FOODS   1.58 -5275.491082     True
# ...          ...      ...        ...    ...          ...      ...
# 56619 2011-12-25     WI_3  HOUSEHOLD   0.00 -2244.693915     True
# 56985 2012-12-25     WI_3  HOUSEHOLD   0.00 -2328.663615     True
# 57350 2013-12-25     WI_3  HOUSEHOLD   0.00 -2412.403890     True
# 57715 2014-12-25     WI_3  HOUSEHOLD   0.00 -2496.144164     True
# 58080 2015-12-25     WI_3  HOUSEHOLD   0.00 -2579.884439     True
#
# [140 rows x 6 columns]

# %% [markdown]
# It turns out that when we filter and zoom into those outlying points with sales very close to 0, they seem to generally occur on 25th Dec. Seems likely due to Christmas... Turns out when you spoke to the data owner, it was revealed that the stores close on Christmas hence the close to zero sales.
#
# Let's mark these as outliers for the time being although we will need to take care to set predicted sales on Christmas to zero later.

# %%
merged.iloc[56619]
# Out:
# date        2011-12-25 00:00:00
# store_id                   WI_3
# cat_id                HOUSEHOLD
# sales                       0.0
# dtrend             -2244.693915
# anomaly                    True
# Name: 56619, dtype: object

# %% [markdown]
# <ins>Instructions</ins>:<br>
# - Mark any additional points as outliers if necessary in your `anomaly` column

# %%
merged.loc[(merged['anomaly'] == False) & (abs(merged['sales']) < 100),'anomaly'] = True

# %%
# sample one of the store category to see how our outlier detection performs
def visualize_outliers(store, category):
    # visualization of outliers detected
    plt.plot(merged[(merged['cat_id']==category) & (merged['store_id'] == store)].date,
             merged[(merged['cat_id']==category) & (merged['store_id'] == store)].dtrend,lw = .5)
    
    plt.scatter(merged[(merged['anomaly'] == True) & (merged['cat_id']==category) & (merged['store_id'] == store)].date,
                merged[(merged['anomaly'] == True) & (merged['cat_id']==category) & (merged['store_id'] == store)].dtrend,color='r')
# sample one of the store category to see how our outlier detection performs
for i in cat:
    for j in stores:
        plt.title(f'{i} in {j}')
        visualize_outliers(j, i)
        plt.show()

# %% [markdown]
# Finally, we will need to set our outliers to null sales value. In reality, we should talk to the data owner to find out the reasons for these outliers and decide if they are legitimate data points (e.g. the Christmas points) or erroneous points.
#
# For the Christmas data points, they reflect the calendar effect and in some models, we can leave these data points as they are and add in covariates indicating these calendar effects into the model. However for us, we will be using univariate model and it would better for us to remove these calendar effects.
#
# Before we set the outliers to null sales value, we can check for other null sales values if any and perform imputation in our next data quality check.

# %% [markdown]
# ### Data quality issue - Missing data

# %% [markdown]
# First let's check for missing sales value. Then we proceed to set outlier to null sales value as mentioned in previous data quality check. And finally perform imputation of sales.

# %% [markdown]
# <ins>Instructions</ins>:<br>
# - Check how many rows have missing sales value

# %% [markdown]
# <ins>Hints</ins> (click when needed):<br>
# - [Pandas isna](https://pandas.pydata.org/docs/reference/api/pandas.Series.isna.html)

# %%
# check number of rows with missing sales
any(merged['sales'].isna())
# Out:
# False

# %% [markdown]
# Good, seems like no missing sales. Well in fact, we knew there's no missing sales when we were previewing the data. But this is just for procedure.
#
# Next we can set our outliers to null sales value.

# %% [markdown]
# <ins>Instructions</ins>:<br>
# - Set outliers to null sales value

# %%
# set outlier to null sales value
merged.loc[merged['anomaly'] == True,'sales'] = np.nan

# %%
merged[merged.anomaly == True]
# Out:
#             date store_id     cat_id  sales       dtrend  anomaly
# 330   2011-12-25     TX_1      FOODS    NaN -4325.732392     True
# 696   2012-12-25     TX_1      FOODS    NaN -4564.055431     True
# 1061  2013-12-25     TX_1      FOODS    NaN -4800.147315     True
# 1426  2014-12-25     TX_1      FOODS    NaN -5039.399199     True
# 1791  2015-12-25     TX_1      FOODS    NaN -5275.491082     True
# ...          ...      ...        ...    ...          ...      ...
# 56619 2011-12-25     WI_3  HOUSEHOLD    NaN -2244.693915     True
# 56985 2012-12-25     WI_3  HOUSEHOLD    NaN -2328.663615     True
# 57350 2013-12-25     WI_3  HOUSEHOLD    NaN -2412.403890     True
# 57715 2014-12-25     WI_3  HOUSEHOLD    NaN -2496.144164     True
# 58080 2015-12-25     WI_3  HOUSEHOLD    NaN -2579.884439     True
#
# [155 rows x 6 columns]

# %%
merged.iloc[56619]
# Out:
# date        2011-12-25 00:00:00
# store_id                   WI_3
# cat_id                HOUSEHOLD
# sales                       NaN
# dtrend             -2244.693915
# anomaly                    True
# Name: 56619, dtype: object

# %% [markdown]
# We can now proceed to impute the missing sales. In our case, we have no extended missing sales period and the number of data points with missing sales is little compared to the total number of data points. Hence, we shall adopt linear interpolation method.
#
# First, we need to set the `date`, `store_id` and `cat_id` columns as index.

# %% [markdown]
# <ins>Instructions</ins>:<br>
# - Impute the missing sales using linear interpolation method.

# %% [markdown]
# <ins>Hints</ins> (click when needed):<br>
# - [Pandas interpolate](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.interpolate.html)

# %%
# impute missing sales
merged['sales'].interpolate(method='linear',inplace=True)

# %%
merged[merged['anomaly'] == True].sales
# Out:
# 330      4965.810
# 696      4672.545
# 1061     4423.010
# 1426     5153.815
# 1791     5259.010
#            ...
# 56619    1949.690
# 56985    1987.205
# 57350    1861.885
# 57715    2344.820
# 58080    3004.925
# Name: sales, Length: 155, dtype: float64

# %%
# sample one of the store category to see how our outlier detection performs
def visualize_outliers(store, category):
    # visualization of outliers detected

    plt.plot(merged[(merged['cat_id']==category) & (merged['store_id'] == store)].date,
             merged[(merged['cat_id']==category) & (merged['store_id'] == store)].sales,lw = .5,alpha=0.5)
    plt.scatter(merged[(merged['anomaly'] == True) & (merged['cat_id']==category) & (merged['store_id'] == store)].date,
                merged[(merged['anomaly'] == True) & (merged['cat_id']==category) & (merged['store_id'] == store)].sales,color='r')
    
    
# sample one of the store category to see how our outlier detection performs
for i in cat:
    for j in stores:
        plt.title(f'{i} in {j}')
        visualize_outliers(j, i)
        plt.show()

# %% [markdown]
# With these data quality checks done, we have completed Milestone 1 and prepared our preprocessed data. Good job!
#
# Now let's save our preprocessed data as `sales_processed.csv` in the data folder.

# %% [markdown]
# <ins>Instructions</ins>:<br>
# - Save the preprocessed data as `sales_processed.csv` in the data folder

# %% [markdown]
# <ins>Hints</ins> (click when needed):<br>
# - [Pandas write CSV](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html)

# %%
# write to CSV
merged.to_csv('sales_processed.csv')
